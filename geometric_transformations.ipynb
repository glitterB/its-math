# %% [markdown]
# # Geometric Transformations
#
# Let's now understand basic *Geometric Transformation* which are-
#
# - Translate
# - Scaling
# - Reflection
# - Rotation
#
# The basic mathematical equation for transformation is given by:
#
# $P^{*} = \left[T\right].P$
#
# where,
# $P^{*}$ is new coordinates
#
# $[T]$ is transfomation matrix
#
# $P$ is old coordinates

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

# %%
#geometry (Triangle)
p = np.array([[10,10,20],
              [20,10,10],
              [1,1,1]])

#Visualizing
fig,ax = plt.subplots()
ax.add_patch(Polygon(p[:len(p)-1,:].T, facecolor = 'k'))

ax.set_xlim([0,30])
ax.set_ylim([0,30])
ax.set_title("Geometry")
plt.show()

# %% [markdown]
# ### 1) Translate
#
# This moves geometric entity in new position but parallel to old one.
#
# Mathematically
#
# $\left[P^{*}\right]=$
# $
# \left[\begin{array}
# 11&0&x_t\\
# 0&1&y_t \\
# 0&0&1
# \end{array}\right]
# $
# $\left\{\begin{array}
# xx\\y\\1
# \end{array}\right\} $
#
# where $x_t~\&~y_t$ are translation distances.

# %%
def translate(p,x_t=1,y_t=1):
    
    #translate matrix
    translate = np.array([[1,0,x_t],
                          [0,1,y_t],
                          [0,0,1]])

    #translated geometry
    
    return translate@p


y_t = translate(p,x_t=20,y_t=10)
p_t = Polygon(y_t[:len(y_t)-1,:].T, facecolor = 'b')

fig,ax = plt.subplots()
ax.add_patch(Polygon(p[:len(p)-1,:].T, facecolor = 'k'))
ax.add_patch(p_t)
ax.set_xlim([0,45])
ax.set_ylim([0,35])
ax.set_title("Translate")
plt.show()

# %% [markdown]
# ### 2) Scale
#
# This enlarge or shortens the geometric entity.
#
# Mathematically
#
# $\left[P^{*}\right]=$
# $
# \left[\begin{array}
# ss_x&0&0\\
# 0&s_y&0 \\
# 0&0&1
# \end{array}\right]
# $
# $\left\{\begin{array}
# xx\\y\\1
# \end{array}\right\} $
#
# where $sx~\&~sy$ are scaling factors.

# %%
def scale(p,sx=1,sy=1):
    
    #translate matrix
    scale = np.array([[sx,0,0],
                  [0,sy,0],
                  [0,0,1]])

    #translated geometry
    
    return scale@p

y_t = scale(p,sx=2,sy=1.5)
p_t = Polygon(y_t[:len(y_t)-1,:].T, facecolor = 'b')

fig,ax = plt.subplots()
ax.add_patch(Polygon(p[:len(p)-1,:].T, facecolor = 'k'))
ax.add_patch(p_t)
ax.set_xlim([0,50])
ax.set_ylim([0,35])
ax.set_title("Scale")
plt.show()

# %% [markdown]
# ### 3) Reflection
#
# A copy of object being reflected along a line.
#
# **a) Reflection along Origin**
#
# Mathematically,
#
# $\left[P^{*}\right]=$
# $
# \left[\begin{array}
# 1-1&0&0\\
# 0&-1&0 \\
# 0&0&1
# \end{array}\right]
# $
# $\left\{\begin{array}
# xx\\y\\1
# \end{array}\right\} $
# ---
# **b) Reflection along X axis**
#
# Mathematically,
#
# $\left[P^{*}\right]=$
# $
# \left[\begin{array}
# 11&0&0\\
# 0&-1&0 \\
# 0&0&1
# \end{array}\right]
# $
# $\left\{\begin{array}
# xx\\y\\1
# \end{array}\right\} $
# ---
# **c) Reflection along Y axis**
#
# Mathematically,
#
# $\left[P^{*}\right]=$
# $
# \left[\begin{array}
# 1-1&0&0\\
# 0&1&0 \\
# 0&0&1
# \end{array}\right]
# $
# $\left\{\begin{array}
# xx\\y\\1
# \end{array}\right\} $
# ---
# **d) Reflection along Y==X**
#
# Mathematically,
#
# $\left[P^{*}\right]=$
# $
# \left[\begin{array}
# 00&1&0\\
# 1&0&0 \\
# 0&0&1
# \end{array}\right]
# $
# $\left\{\begin{array}
# xx\\y\\1
# \end{array}\right\} $

# %%
def reflect(p,x=False,y=False,o=True):
    
    if x:
        reflection_x = np.array([[1,0,0],
                                [0,-1,0],
                                [0,0,1]])
        return reflection_x@p
    
    if y:
        reflection_y = np.array([[-1,0,0],
                                [0,1,0],
                                [0,0,1]])
        return reflection_y@p
    
    if o:
        reflection_origin = np.array([[-1,0,0],
                                      [0,-1,0],
                                      [0,0,1]])
        return reflection_origin@p
    else:
        reflection_yx = np.array([[0,1,0],
                                      [1,0,0],
                                      [0,0,1]])
        return reflection_yx@p
#Origin
y_t = reflect(p)
p_t = Polygon(y_t[:len(y_t)-1,:].T, facecolor = 'b')
fig,ax = plt.subplots(1,3,figsize=[9,4])
ax[0].add_patch(Polygon(p[:len(p)-1,:].T, facecolor = 'k'))
ax[0].add_patch(p_t)
ax[0].set_xlim([-25,25])
ax[0].set_ylim([-25,25])
ax[0].set_title("Reflection along origin")

#X
y_t = reflect(p,x=True,o=False)
p_t = Polygon(y_t[:len(y_t)-1,:].T, facecolor = 'b')
ax[1].add_patch(Polygon(p[:len(p)-1,:].T, facecolor = 'k'))
ax[1].add_patch(p_t)
ax[1].set_xlim([-25,25])
ax[1].set_ylim([-25,25])
ax[1].set_title("Reflection along X axis")

#Y
y_t = reflect(p,y=True,o=False)
p_t = Polygon(y_t[:len(y_t)-1,:].T, facecolor = 'b')
ax[2].add_patch(Polygon(p[:len(p)-1,:].T, facecolor = 'k'))
ax[2].add_patch(p_t)
ax[2].set_xlim([-25,25])
ax[2].set_ylim([-25,25])
ax[2].set_title("Reflection along Y axis")

plt.show()

# %% [markdown]
# ### 4) Rotation
#
# Rotation will rotate the geometric entity with given angle $\theta$.
#
# Mathematically
#
# **a) Rotation along Z axis(Anti-clockwise)**
#
# Mathematically,
#
# $\left[P^{*}\right]=$
# $
# \left[\begin{array}
# ccos(\theta)&sin(\theta)&0\\
# -sin(\theta)&cos(\theta)&0 \\
# 0&0&1
# \end{array}\right]
# $
# $\left\{\begin{array}
# xx\\y\\1
# \end{array}\right\} $
# ---
# **b) Rotation along X axis**
#
# $\left[P^{*}\right]=$
# $
# \left[\begin{array}
# 11&0&0\\
# 0&ccos(\theta)&sin(\theta)\\
# 0&-sin(\theta)&cos(\theta)
# \end{array}\right]
# $
# $\left\{\begin{array}
# xx\\y\\1
# \end{array}\right\} $
# ---
# **c) Rotation along Y axis**
#
# $\left[P^{*}\right]=$
# $
# \left[\begin{array}
# ccos(\theta)&0&sin(\theta)\\
# 0&1&0\\
# -sin(\theta)&0&cos(\theta)
# \end{array}\right]
# $
# $\left\{\begin{array}
# xx\\y\\1
# \end{array}\right\} $

# %%
def rotate(p,x=False,y=False,z=True,ang=45):

    t=ang*(np.pi/180) #angle of rotation (deg)
    if x:
        
        rotation_x = np.array([[1,0,0],
                               [0,np.cos(t),-np.sin(t)],
                                [0,np.sin(t),np.cos(t)]])
        return rotation_x@p
    
    if y:
        rotation_y = np.array([[np.cos(t),0,-np.sin(t)],
                           [0,1,0],
                            [np.sin(t),0,np.cos(t)]])
        return rotation_y@p
        
    if z:
        rotation_z = np.array([[np.cos(t),-np.sin(t),0],
                            [np.sin(t),np.cos(t),0],
                            [0,0,1]])
        return rotation_z@p
#X
y_t = rotate(p,x=True)
p_t = Polygon(y_t[:len(y_t)-1,:].T, facecolor = 'b')
fig,ax = plt.subplots(1,3,figsize=[9,4])
ax[0].add_patch(Polygon(p[:len(p)-1,:].T, facecolor = 'k'))
ax[0].add_patch(p_t)
ax[0].set_xlim([-25,25])
ax[0].set_ylim([-25,25])
ax[0].set_title("Rotation along X")

#Y
y_t = rotate(p,y=True)
p_t = Polygon(y_t[:len(y_t)-1,:].T, facecolor = 'b')
ax[1].add_patch(Polygon(p[:len(p)-1,:].T, facecolor = 'k'))
ax[1].add_patch(p_t)
ax[1].set_xlim([-25,25])
ax[1].set_ylim([-25,25])
ax[1].set_title("Rotation along Y axis")

#Z
y_t = rotate(p)
p_t = Polygon(y_t[:len(y_t)-1,:].T, facecolor = 'b')
ax[2].add_patch(Polygon(p[:len(p)-1,:].T, facecolor = 'k'))
ax[2].add_patch(p_t)
ax[2].set_xlim([-25,25])
ax[2].set_ylim([-25,25])
ax[2].set_title("Rotaion along Z axis")

plt.show()

# %% [markdown]
# In this way, geometric entities can we transformed.
